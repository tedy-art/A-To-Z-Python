# %% [markdown]
# # Python Polymorphism
#
# The word Polymorphism means "Many Forms", and in programming it refers to method/function/operators with the same name that can be executed on many objects or classes.

# %% [markdown]
# **Function Polymorphism :**
#
# python function that can be used on different objects is the `len()` function.

# %%
# string
myStr = "Hello World!"

print(len(myStr))
# Out:
# 12

# %%
# tuple
mytuple = ("apple", "banana", "cherry")
print(len(mytuple))
# Out:
# 3

# %%
# dictionary
thisdict = {
    "brand":"Ford",
    "model":"Mustang",
    "year":1964
}

print(len(mytuple))
# Out:
# 3

# %% [markdown]
# # Class Polymorphism
#
# Polymorphism is often used in class methods, where we can have multiple classes with same method name.
#
# For Example:
#
# say we have three classes: `car`, `Boat` and `Plane`, and they all have a method called `mave()`.

# %%
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def move(self):
        print("Drive!")

class Boat:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def move(self):
        print('sail!')

class Plane:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def move(self):
        print('fly!')

car1 = Car("Ford", "Mustang")
boat1 = Boat("Ibiza", "Touring 20")
plane1 = Plane("Boeing", "747")

for x in (car1, boat1, plane1):
    x.move()
# Out:
# Drive!
# sail!
# fly!

# %% [markdown]
# # Inheritance Class Polymorphism

# %% [markdown]
# Polymorphism allow methods to perform different tasks based on the object they are acting upon.
#
# When combined with inheritance, polymorphism enables child classes to provide specific implimentations of methods that are defined in their parent classes.

# %% [markdown]
# 1. Inheritance:
#    - Enables a child class to inherit attributes and methods from a paranet class.

# %%
class Parent:
    def method1(self):
        print("Parent Method")

class Child(Parent):
    def method2(self):
        print("Child Class")

child_object = Child()
child_object.method1()
child_object.method2()
# Out:
# Parent Method
# Child Class

# %% [markdown]
# 2. Polymorphism
#    - Achieved through method overriding, where a child class provides a specific implementation of a method already defined in the parent class.
#    - Allows the same method name to behave differently based on the objects calling it.

# %%
class Animal:
    def sound(self):
        raise NotImplementedError("SUbclass should implemented this!")

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return "Meow"

# using polumorphism with inheritance
# create instance of `Dog` and `Cat`
# call the `sound` method on each instance
dog = Dog()
cat = Cat()

animals = [dog, cat]
for animal in animals:
    print(animal.sound())
# Out:
# Bark
# Meow

# %% [markdown]
# ### Explanation:
#
# **Inheritance:**
#
# - `Dog` and `Cat` classes inherit from `Animal` class.
# - They override the `sound` method to provide specific implementations.
#
# **Polymorphism:**
#
# - The `sound` method in `Animal` is a placeholder (abstract method).
# - When `sound` is called on a `Dog` object, it prints "Bark".
# - When `sound` is called on a `Cat` object, it prints "Meow".
# - The `for loop` demonstrates polymorphic behavior, where the same method (`sound`) acts differently based on the object type.
#
#
# **Benefits:**
# - **Code Reusability:** Common methods are defined in the parent class and reused in child classes.
# - **Flexibility:** New child classes can be added without changing the existing code.
# - **Maintainability:** Polymorphic code is easier to maintain and extend.

# %%
# Example
# Create a class called Vehicle and make Car, Boat, Plane child classes of Vehicle:

class Vehicle:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Move!")

class Car(Vehicle):
  pass

class Boat(Vehicle):
  def move(self):
    print("Sail!")

class Plane(Vehicle):
  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang") #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747") #Create a Plane object

for x in (car1, boat1, plane1):
  print(x.brand)
  print(x.model)
  x.move()
# Out:
# Ford
# Mustang
# Move!
# Ibiza
# Touring 20
# Sail!
# Boeing
# 747
# Fly!
